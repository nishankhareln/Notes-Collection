# %% [markdown]
# -----------------------------------------Time Series Data Analysis---------------------------------------------------

# %% [markdown]
# Can We Use Time Series for Any Analysis?
# 👉 Not always. Time series is a special kind of analysis, mainly used when:
#
# Data is time-dependent
#
# You want to forecast or detect trends over time
#
# Order of data matters (past affects future)

# %% [markdown]
# Like we had a salry of employee of annual we cannot use, but those employee data like
# 101 kai data 3-4 palta cha , 2-3 barsa ra ssabaiko data testaii cha bhane time series can be uesd.

# %% [markdown]
# ----------------------------------------------------------------------------
# Time Series is a set of statistics usually collected at regular intervals.Time series data is just data that is collected over time, in order.
#
# Imagine you're writing down the temperature outside your house every hour. You’ll end up with a list like this:
# | Time     | Temperature (°C)
# | -------- | ----------------
# | 9:00 AM  | 20
# | 10:00 AM | 21
# | 11:00 AM | 23
# | 12:00 PM | 25
#
# This is time series data because:
#
# Each data point has a time (timestamp).
#
# The data is recorded in a specific order.
#
# It helps us see how things change over time.

# %% [markdown]
# -----------------------Important components in Time series:--------------------------------------------------------------------
#
#
# 1.Trend: Trend represents the long-term movement or directionality of the data over time. It captures the overall tendency of the series to increase, decrease, or remain stable. Trends can be linear, indicating a consistent increase or decrease, or nonlinear, showing more complex patterns.
#         eg:uptrend , down trend like which fluctuates
#         ![alt text](image.png)
#
# 2.

# %% [markdown]
# 2.Seasonality:
# ----------Seasonality refers to periodic fluctuations or patterns that occur at regular intervals within the time series. These cycles often repeat annually, quarterly, monthly, or weekly and are typically influenced by factors such as seasons, holidays, or business cycles.
#
# 3.Cyclic variations: Cyclical variations are longer-term fluctuations in the time series that do not have a fixed period like seasonality. These fluctuations represent economic or business cycles, which can extend over multiple years and are often associated with expansions and contractions in economic activity.
#
# 4.Irregularity (or Noise): Irregularity, also known as noise or randomness, refers to the unpredictable or random fluctuations in the data that cannot be attributed to the trend, seasonality, or cyclical variations. These fluctuations may result from random events, measurement errors, or other unforeseen factors. Irregularity makes it challenging to identify and model the underlying patterns in the time series data.

# %% [markdown]
# ---------------------------------------Different Time series visualization graphs-----------------------------------
# 1.Line Plots: Line plots display data points over time, allowing easy observation of trends, cycles, and fluctuations.
# 2.Seasonal Plots: These plots break down time series data into seasonal components, helping to visualize patterns within specific time periods.
# 3.Histograms and Density Plots: Shows the distribution of data values over time, providing insights into data characteristics such as skewness and kurtosis.
# 4.Autocorrelation and Partial Autocorrelation Plots: These plots visualize correlation between a time series and its lagged values, helping to identify seasonality and lagged relationships.
# 5.Spectral Analysis: Spectral analysis techniques, such as periodograms and spectrograms, visualize frequency components within time series data, useful for identifying periodicity and cyclical patterns.
# 6.Decomposition Plots: Decomposition plots break down a time series into its trend, seasonal, and residual components, aiding in understanding the underlying patterns.

# %% [markdown]
# 📊 How Time Series is Used in Data Analysis
# 1. Tracking Trends
# We look at how something changes over time.
#
# 🧠 Example:
# A company tracks its monthly sales for a year.
# We can spot a trend — e.g., sales are going up gradually.
#
# # Example: Using pandas to see a trend
# df['sales'].plot()

# %% [markdown]
# 2.identifying seasonality:
# -----------------We look for regular patterns that repeat

# %% [markdown]
# 3.Making Forecast:
# --------------------We use past data to predict the future.
#                     from statsmodels.tsa.arima.model import ARIMA
#                     model = ARIMA(df['visits'], order=(1,1,1))
#                     model.fit().forecast(steps=7)
#
#
#
# | Tool           | Use                                   |
# | -------------- | ------------------------------------- |
# | `pandas`       | Handling time-indexed data            |
# | `matplotlib`   | Plotting trends over time             |
# | `statsmodels`  | Statistical forecasting (ARIMA, etc.) |
# | `Prophet`      | Easy forecasting by Facebook          |
# | `scikit-learn` | Machine learning models               |

# %% [markdown]
# plotting:
# 1.Line Plots:
# ---------DataFrame.plot.line(x, y)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a list of data to be represented in x-axis
days = [ 'Saturday' , 'Sunday' , 'Monday' , 'Tuesday' ,
        'Wednesday' , 'Thursday' , 'Friday' ]

# Create a list of data to be 
# represented in y-axis
calories = [ 1670 , 2011 , 1853 , 2557 ,
            1390 , 2118 , 2063 ]

# Create a dataframe using the two lists
df_days_calories = pd.DataFrame(
    { 'day' : days , 'calories' : calories })

df_days_calories

print("line plot with x-axis as day and y-axis as calories")

df_days_calories.plot( 'day' , 'calories' )
# Out:
# line plot with x-axis as day and y-axis as calories
# <Axes: xlabel='day'>

# %%
import pandas as pd

# Create a list of data to
# be represented in x-axis
subjects = [ 'Math' , 'English' , 'History' ,
            'Chem' , 'Geo' , 'Physics' , 'Bio' , 'CS' ]

# Create a list of data to be 
# represented in y-axis
stress = [ 9 , 3 , 5 , 1 , 8 , 5 , 10 , 2 ]

# Create second list of data
# to be represented in y-axis
grades = [ 15 , 10 , 7 , 8 , 11 , 8 , 17 , 20 ]

# Create a dataframe using the three lists
df = pd.DataFrame(list(zip( stress , grades )),
                  index = subjects , 
                  columns = [ 'Stress' , 'Grades' ])
df
# Out:
#          Stress  Grades
# Math          9      15
# English       3      10
# History       5       7
# Chem          1       8
# Geo           8      11
# Physics       5       8
# Bio          10      17
# CS            2      20

# %%
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# #Seasonal Patterns:
# ![alt text](image-1.png)

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------
# 3.![alt text](image-2.png)

# %% [markdown]
# -------------------------
# Decomposition Plot:
#
# ![alt text](image-3.png)

# %% [markdown]
# #-----------------
# Spectral Analysis:
# ![alt text](image-4.png)

# %% [markdown]
# --------------------------------------------Preprocessing Time Series Data
# Time series preprocessing refers to the steps taken to clean, transform, and prepare time series data for analysis or forecasting. It involves techniques aimed at improving data quality, removing noise, handling missing values, and making the data suitable for modeling. Preprocessing tasks may include removing outliers, handling missing values through imputation, scaling or normalizing the data, detrending, deseasonalizing, and applying transformations to stabilize variance. The goal is to ensure that the time series data is in a suitable format for subsequent analysis or modeling.
#
# Handling Missing Values : Dealing with missing values in the time series data to ensure continuity and reliability in analysis.
# Dealing with Outliers: Identifying and addressing observations that significantly deviate from the rest of the data, which can distort analysis results.
# Stationarity and Transformation: Ensuring that the statistical properties of the time series, such as mean and variance, remain constant over time. Techniques like differencing, detrending, and deseasonalizing are used to achieve stationarity.

# %% [markdown]
# Techniques for time series data analysis:
# ------------------------------------------------
# 1. Stationarity
# A time series is stationary if its statistical properties (mean, variance) do not change over time. Stationary data is required for many time series models like ARIMA.
#
# Why? Most time series models assume constant patterns; stationarity ensures this.
#
# 2. Differencing
# Differencing involves subtracting the current value from the previous value to remove trends or seasonality.
#
# Why? Helps make a non-stationary time series stationary.
#
# 3. Detrending
# This removes a trend component from a time series, typically by subtracting the trend line (like linear regression).
#
# Why? To focus analysis on the fluctuations rather than long-term growth or decline.
#
# 4. Deseasonalizing
# This technique removes the seasonal component from the time series data.
#
# Why? Makes the series easier to model and forecast by removing repeated seasonal effects.
#
# 5. Moving Average
# A technique that smooths out short-term fluctuations and highlights longer-term trends by averaging values over a defined window.
#
# Why? Useful for trend analysis and noise reduction.
#
# 6. Exponential Moving Average (EMA)
# A weighted moving average that gives more importance to recent data points.
#
# Why? Responds faster to recent changes than simple moving average.
#
# 7. Missing Value Imputation
# Filling in gaps in the time series where data is missing using methods like forward fill, backward fill, interpolation, or model-based imputation.
#
# Why? Many time series models can’t handle missing values directly.
#
# 8. Outlier Detection and Removal
# Identifying and handling abnormal spikes or drops in data which can skew analysis or model predictions.
#
# Why? Outliers can distort trend and seasonality detection and forecasting accuracy.
#
# 9. Time Alignment
# Aligning time indices of different time series or adjusting time stamps to a regular frequency.
#
# Why? Ensures consistency in analysis and correct correlation between variables.
#
# 10. Data Transformation
# Applying functions like log, square root, or Box-Cox to stabilize variance or reduce skewness.
#
# Why? Some transformations make data more suitable for modeling (e.g., log to handle exponential growth).
#
# 11. Scaling
# Adjusting the range of data using techniques like Min-Max scaling or Standardization (z-score).
#
# Why? Many models (like neural networks) perform better on scaled data.
#
# 12. Normalization
# A type of scaling that brings data into a common range, typically [0,1].
#
# Why? Especially useful when combining multiple features in machine learning models.

# %% [markdown]
# -----------------------------------------------------------
#
# List of Time Series Preprocessing Techniques:
#
# 📌 1. Stationarity Handling Techniques
# These are used to make the time series stationary:
#
# a.Stationarity
#
# b.Differencing
#
# c.Detrending
#
# d.Deseasonalizing
#
# 📌 2. Smoothing Techniques
# These help reduce noise and highlight trends:
#
# a.Moving Average
#
# b.Exponential Moving Average (EMA)
#
# 📌 3. Data Cleaning Techniques
# These prepare the data for analysis:
#
# a.Missing Value Imputation
#
# b.Outlier Detection and Removal
#
# c.Time Alignment
#
# 📌 4. Transformation & Scaling Techniques
# These adjust data distribution and scale:
#
# Data Transformation (log, square root, Box-Cox)
#
# Scaling (Standardization, Min-Max)
#
# Normalization (rescaling to [0, 1])

# %% [markdown]
# -----------------------Performance metrics----------------------------
# Performance Metrics:
# Performance metrics are quantitative measures used to evaluate the accuracy and effectiveness of time series forecasts. These metrics provide insights into how well a forecasting model performs in predicting future values based on historical data. Common performance metrics which can be used for time series include:
#
# Mean Absolute Error (MAE): Measures the average magnitude of errors between predicted and actual values.
#
# Mean Absolute Percentage Error (MAPE): Calculates the average percentage difference between predicted and actual values.
#
# Mean Squared Error (MSE): Computes the average squared differences between predicted and actual values.
#
# Root Mean Squared Error (RMSE): The square root of MSE, providing a measure of the typical magnitude of errors.
#
# Forecast Bias: Determines whether forecasts systematically overestimate or underestimate actual values.
#
# Forecast Interval Coverage: Evaluates the percentage of actual values that fall within forecast intervals.
#
# Theil's U Statistic: Compares the performance of the forecast model to a naïve benchmark model.
